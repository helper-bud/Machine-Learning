# %%
# !pip install opencv-python
import numpy as np
from google.colab.patches import cv2_imshow # needed for collab
import cv2
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.5)

# %%
img = cv2.imread("/content/test.jpg") # importing image
print(img.shape) #> (512, 512, 3) (width, height, number of your channels)
# Out:
# (150, 150, 3)

# %%
image_resize = cv2.resize(img,(300,200)) #(which image,(width, height))
print(image_resize.shape) #> (200, 300, 3)
# Out:
# (200, 300, 3)

# %%
image_cropped = img[0:200, 200:500] #(height-> 0  to 200  , width -> 200 to 500)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F4902CC8CD0>

# %%
cv2_imshow(image_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x7F4902D32E10>

# %%
cv2_imshow(image_cropped)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-22-e1ad4a6796de> in <module>()
# ----> 1 cv2_imshow(image_cropped)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      26       a = cv2.cvtColor(a, cv2.COLOR_BGRA2RGBA)
#      27     else:
# ---> 28       a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
#      29   display.display(PIL.Image.fromarray(a))
#      30
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
